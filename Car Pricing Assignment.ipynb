# %%
# Loafd the Data

import pandas as pd

# %%
car_df = pd.read_csv("/content/drive/MyDrive/Datasets/Car prince ds/CarPrice_Assignment.csv")

car_df['cylindernumber'] = car_df['cylindernumber'].map({'four': 4, 'six':6, 'five':5, 'three':3, 'twelve':13, 'two':2, 'eight':8}).astype(int)                                            

car_df['fueltype'] = car_df['fueltype'].map({'gas': 0, 
                                             'diesel' : 1}).astype(int)
car_df['aspiration'] = car_df['aspiration'].map({'std': 0, 
                                             'turbo' : 1}).astype(int) 

car_df['carbody'] = car_df['carbody'].map({'convertible':0, 'hatchback':1, 'sedan':2,
                                           'wagon':3, 'hardtop':4}).astype(int)                                  

car_df['drivewheel'] = car_df['drivewheel'].map({'rwd':0, 'fwd':1, '4wd':2}).astype(int)

car_df['enginelocation'] = car_df['enginelocation'].map({'front':0, 'rear':1}).astype(int)  

car_df['enginetype'] = car_df['enginetype'].map({'dohc':0, 'ohcv':1, 'ohc':2, 'l':3, 'rotor':4
                                                , 'ohcf':5, 'dohcv':6}).astype(int)

car_df['fuelsystem'] = car_df['fuelsystem'].map({'mpfi':0, '2bbl':1, 'mfi':2, '1bbl':3, 'spfi':4,
                                                 '4bbl':5, 'idi':6, 'spdi':7}).astype(int) 

car_df['doornumber'] = car_df['doornumber'].map({'two':0, 'four':1}).astype(int)                                                 

car_df.head()
# Out:
#    car_ID  symboling                   CarName  ...  citympg  highwaympg    price
# 0       1          3        alfa-romero giulia  ...       21          27  13495.0
# 1       2          3       alfa-romero stelvio  ...       21          27  16500.0
# 2       3          1  alfa-romero Quadrifoglio  ...       19          26  16500.0
# 3       4          2               audi 100 ls  ...       24          30  13950.0
# 4       5          2                audi 100ls  ...       18          22  17450.0
#
# [5 rows x 26 columns]

# %%
car_df.doornumber.unique()
# Out:
# array([0, 1])

# %%
car_df['CarName'] = car_df['CarName'].map({'alfa-romero giulia': 0 , 'alfa-romero stelvio': 1 ,
                                           'alfa-romero Quadrifoglio': 2 , 'audi 100 ls': 3, 'audi 100ls': 4 ,
                                           'audi fox': 5 , 'audi 5000': 6 , 'audi 4000': 7 , 'audi 5000s (diesel)': 8 ,
                                           'bmw 320i': 9  , 'bmw x1': 10 ,  'bmw x3': 11  , 'bmw z4': 12 ,
                                           'bmw x4': 13 ,  'bmw x5': 14 ,  'chevrolet impala': 15  ,
                                           'chevrolet monte carlo': 16  , 'chevrolet vega 2300': 17  ,
                                           'dodge rampage': 18 ,  'dodge challenger se': 19  ,
                                           'dodge d200': 20 ,  'dodge monaco (sw)': 21 ,  'dodge colt hardtop': 22  ,
                                           'dodge colt (sw)': 23 ,  'dodge coronet custom': 24 , 
                                            'dodge dart custom': 25  , 'dodge coronet custom (sw)': 26 , 
                                            'honda civic': 27 ,  'honda civic cvcc': 28  , 'honda accord cvcc': 29 ,
                                            'honda accord lx': 30  , 'honda civic 1500 gl': 31  , 'honda accord': 32 ,
                                            'honda civic 1300': 33  , 'honda prelude': 34 , 
                                           'honda civic (auto)': 35  , 'isuzu MU-X': 36 ,  'isuzu D-Max ': 37  ,
                                           'isuzu D-Max V-Cross': 38 ,  'jaguar xj': 39 ,  'jaguar xf': 40  ,
                                           'jaguar xk': 35 , 'maxda rx3': 36  , 'maxda glc deluxe': 37  ,
                                           'mazda rx2 coupe': 38  , 'mazda rx-4': 39 , 'mazda glc deluxe': 40  ,
                                           'mazda 626': 41 ,  'mazda glc': 42  , 'mazda rx-7 gs': 43  ,
                                           'mazda glc 4': 44 ,  'mazda glc custom l': 45  ,
                                           'mazda glc custom': 46  , 'buick electra 225 custom': 47  ,
                                           'buick century luxus (sw)': 48  , 'buick century': 49  ,
                                           'buick skyhawk': 50  , 'buick opel isuzu deluxe': 51  ,
                                           'buick skylark': 52  , 'buick century special': 53  , 
                                           'buick regal sport coupe (turbo)': 54  , 'mercury cougar': 55  ,
                                           'mitsubishi mirage': 56  , 'mitsubishi lancer': 57  , 
                                           'mitsubishi outlander': 58  , 'mitsubishi g4': 59  , 
                                           'mitsubishi mirage g4': 60 ,  'mitsubishi montero': 61  ,
                                           'mitsubishi pajero': 62 ,  'Nissan versa': 63 ,
                                           'nissan gt-r': 64 ,  'nissan rogue': 65  ,
                                           'nissan latio': 66  , 'nissan titan': 67  , 'nissan leaf': 68  , 
                                           'nissan juke': 69 ,  'nissan note': 70 ,  'nissan clipper': 71  , 
                                           'nissan nv200': 72  , 'nissan dayz': 73 ,  'nissan fuga': 74  ,
                                           'nissan otti': 75 , 'nissan teana': 76  , 'nissan kicks': 77  ,
                                           'peugeot 504': 78  , 'peugeot 304': 79  , 'peugeot 504 (sw)': 80  ,
                                           'peugeot 604sl': 81 , 'peugeot 505s turbo diesel': 82  ,
                                           'plymouth fury iii': 83  , 'plymouth cricket': 84  , 
                                           'plymouth satellite custom (sw)': 85  , 'plymouth fury gran sedan': 86  ,
                                           'plymouth valiant': 87 ,  'plymouth duster': 88 , 'porsche macan': 89 , 
                                           'porcshce panamera': 90 , 'porsche cayenne': 91 , 'porsche boxter': 92 , 
                                           'renault 12tl': 93,  'renault 5 gtl': 94,  'saab 99e': 95, 
                                           'saab 99le': 96,  'saab 99gle': 97,  'subaru': 98 , 'subaru dl': 99,
                                           'subaru brz': 100 , 'subaru baja': 101 , 'subaru r1': 102 ,
                                           'subaru r2': 103 , 'subaru trezia': 104 , 'subaru tribeca': 105 ,
                                           'toyota corona mark ii': 106 , 'toyota corona':107 ,
                                           'toyota corolla 1200': 108 , 'toyota corona hardtop': 109 ,
                                           'toyota corolla 1600 (sw)': 110 , 'toyota carina': 111 ,
                                           'toyota mark ii': 112 , 'toyota corolla': 113 ,
                                           'toyota corolla liftback': 114 , 'toyota celica gt liftback': 115 ,
                                           'toyota corolla tercel': 116 , 'toyota corona liftback': 117 ,
                                           'toyota starlet': 118 , 'toyota tercel': 119 , 'toyota cressida': 120 , 
                                           'toyota celica gt': 121 , 'toyouta tercel': 122 , 'vokswagen rabbit': 123 ,
                                           'volkswagen 1131 deluxe sedan': 124 , 'volkswagen model 111': 125 ,
                                           'volkswagen type 3': 126 , 'volkswagen 411 (sw)': 127 ,
                                           'volkswagen super beetle': 128 , 'volkswagen dasher': 129 , 
                                           'vw dasher': 130 , 'vw rabbit': 131 , 'volkswagen rabbit': 132 ,
                                           'volkswagen rabbit custom': 133 , 'volvo 145e (sw)': 134 ,
                                           'volvo 144ea': 135 , 'volvo 244dl': 136 , 'volvo 245': 137 , 
                                           'volvo 264gl': 138 , 'volvo diesel': 139 , 'volvo 246':140})                                            
car_df.head()
# Out:
#    car_ID  symboling  CarName  fueltype  ...  peakrpm  citympg  highwaympg    price
# 0       1          3        0         0  ...     5000       21          27  13495.0
# 1       2          3        1         0  ...     5000       21          27  16500.0
# 2       3          1        2         0  ...     5000       19          26  16500.0
# 3       4          2        3         0  ...     5500       24          30  13950.0
# 4       5          2        4         0  ...     5500       18          22  17450.0
#
# [5 rows x 26 columns]

# %%
import numpy as np
import tensorflow as tf
datset_labels = pd.DataFrame(car_df['price'])
dataset_ds =pd.DataFrame(car_df.drop(['price'], axis = 1 ))
dataset = tf.convert_to_tensor(dataset_ds , dtype=tf.float32)
labels = tf.convert_to_tensor(datset_labels , dtype=tf.float32)

# %%
print(dataset.shape)
print(labels.shape)
# Out:
# (205, 25)
# (205, 1)

# %%
df = dataset
df1 = dataset

train_ds = df[:105]
train_labels = labels[:105]

test_ds = df[106:186]
test_labels = labels[106:186]

val_ds = df[186:]
val_labels = labels[186:]

# %%
print(train_ds.shape)
print(train_labels.shape)
print(test_ds.shape)
print(test_labels.shape)
print(val_ds.shape)
print(val_labels.shape)

labels1 = datset_labels[:105]

print(labels1.shape)
print(labels1)
# Out:
# (105, 25)
# (105, 1)
# (80, 25)
# (80, 1)
# (19, 25)
# (19, 1)
# (105, 1)
#        price
# 0    13495.0
# 1    16500.0
# 2    16500.0
# 3    13950.0
# 4    17450.0
# ..       ...
# 100   9549.0
# 101  13499.0
# 102  14399.0
# 103  13499.0
# 104  17199.0
#
# [105 rows x 1 columns]

# %%
train_ds[0].shape
# Out:
# TensorShape([25])

# %%
# import model and layers
from tensorflow.keras import models
from tensorflow.keras import layers

from keras.models import Sequential
from keras.layers import Dense

# %%
#Define model
network = models.Sequential()

# %%
#Add layers
# Layer # 1 

network.add(layers.Dense( 64, activation = 'relu' , input_shape = (25,)))

network.add(layers.Dense(1))

#network.add(layers.Dense(16, activation = 'relu'))

#network.add(layers.Dense(1, activation ='relu'))

# %%
#Complie network

import keras
optimizer = keras.optimizers.Adam(lr=0.1)
network.compile(loss='mse', optimizer=optimizer, metrics =['accuracy'])

#network.compile(optimizer = 'rmsprop' , loss = 'mse' , metrics =['accuracy'], lr  =0.001)

# %%
#fit method

network.fit(train_ds, train_labels, epochs = 20, batch_size =10)
# Out:
# Epoch 1/20
# 11/11 [==============================] - 0s 1ms/step - loss: 221075776.0000 - accuracy: 0.0000e+00
# Epoch 2/20
# 11/11 [==============================] - 0s 1ms/step - loss: 260966756.0000 - accuracy: 0.0000e+00
# Epoch 3/20
# 11/11 [==============================] - 0s 1ms/step - loss: 258915596.0000 - accuracy: 0.0000e+00
# Epoch 4/20
# 11/11 [==============================] - 0s 1ms/step - loss: 265936666.6667 - accuracy: 0.0000e+00
# Epoch 5/20
# 11/11 [==============================] - 0s 1ms/step - loss: 349437573.3333 - accuracy: 0.0000e+00
# Epoch 6/20
# 11/11 [==============================] - 0s 1ms/step - loss: 304570120.0000 - accuracy: 0.0000e+00
# Epoch 7/20
# 11/11 [==============================] - 0s 1ms/step - loss: 284368940.0000 - accuracy: 0.0000e+00
# Epoch 8/20
# 11/11 [==============================] - 0s 1ms/step - loss: 263184481.3333 - accuracy: 0.0000e+00
# Epoch 9/20
# ...

# %%
import numpy as np
import pandas as pd
import tensorflow as tf

dataset = pd.read_csv('Processed Temp.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
ct = ColumnTransformer(transformers = [('encoder', OneHotEncoder(), [0])], remainder = 'passthrough')
X = np.array(ct.fit_transform(X))

X = np.asarray(X)
y = np.asarray(y)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

ann = tf.keras.models.Sequential()
ann.add(tf.keras.layers.Dense(units=19, activation='relu'))
ann.add(tf.keras.layers.Dense(units=19, activation='relu'))
ann.add(tf.keras.layers.Dense(units=1))

ann.compile(optimizer = 'adam', loss = 'mean_squared_error')
ann.fit(X_train, y_train ,batch_size = 32, epochs = 100)

y_pred = ann.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-a177b20daf2c> in <module>()
#       3 import tensorflow as tf
#       4
# ----> 5 dataset = pd.read_csv('Processed Temp.csv')
#       6 X = dataset.iloc[:, :-1].values
#       7 y = dataset.iloc[:, -1].values
#
# ...
